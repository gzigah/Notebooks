# %% [markdown]
# # My first work

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-28bbb38448f8> in <module>
#      20 if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
#      21
# ---> 22 df_data_1 = pd.read_csv(body)
#      23 df_data_1.head()
#
# ...

# %%
body = client_71e9c320a06d4cc293985a491de49be8.get_object(Bucket='projectwork2-donotdelete-pr-y3d86le6dk5i2t',Key='weather-stations20140101-20141231.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body)
df_data_2.head()
# Out:
#                  Stn_Name     Lat     Long Prov   Tm  DwTm    D    Tx  DwTx  \
# 0               CHEMAINUS  48.935 -123.742   BC  8.2   0.0  NaN  13.5   0.0
# 1  COWICHAN LAKE FORESTRY  48.824 -124.133   BC  7.0   0.0  3.0  15.0   0.0
# 2           LAKE COWICHAN  48.829 -124.052   BC  6.8  13.0  2.8  16.0   9.0
# 3        DISCOVERY ISLAND  48.425 -123.226   BC  NaN   NaN  NaN  12.5   0.0
# 4     DUNCAN KELVIN CREEK  48.735 -123.728   BC  7.7   2.0  3.4  14.5   2.0
#
#     Tn  ...  DwP    P%N  S_G    Pd  BS  DwBS  BS%    HDD  CDD   Stn_No
# 0  1.0  ...  0.0    NaN  0.0  12.0 NaN   NaN  NaN  273.3  0.0  1011500
# 1 -3.0  ...  0.0  104.0  0.0  12.0 NaN   NaN  NaN  307.0  0.0  1012040
# 2 -2.5  ...  9.0    NaN  NaN  11.0 NaN   NaN  NaN  168.1  0.0  1012055
# 3  NaN  ...  NaN    NaN  NaN   NaN NaN   NaN  NaN    NaN  NaN  1012475
# 4 -1.0  ...  2.0    NaN  NaN  11.0 NaN   NaN  NaN  267.7  0.0  1012573
#
# [5 rows x 25 columns]

# %%
body = client_71e9c320a06d4cc293985a491de49be8.get_object(Bucket='projectwork2-donotdelete-pr-y3d86le6dk5i2t',Key='data.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_3 = pd.read_csv(body)
df_data_3.head()
# Out:
#    Claim_Period Program_Closure_Flag Report_Data_Status Super_License_Flag  \
# 0        202009                 Open            Partial                  Y
# 1        202009                 Open            Partial                  Y
# 2        202009                 Open            Partial                  N
# 3        202009                 Open            Partial                  Y
# 4        202009                 Open            Partial                  Y
#
#         ProgramTypeName_Value NonProfitFlagDesc_Value  \
# 0            DAY CARE PROGRAM              For Profit
# 1  OUT OF SCHOOL CARE PROGRAM              For Profit
# 2  OUT OF SCHOOL CARE PROGRAM              For Profit
# 3            DAY CARE PROGRAM              For Profit
# 4            DAY CARE PROGRAM              For Profit
#
#   PhysicalAddressLine2_Value Program_Activity_Start_Date  \
# 0              Not Available                  09/25/2020
# 1              Not Available                  09/24/2020
# ...

# %%
a=2
